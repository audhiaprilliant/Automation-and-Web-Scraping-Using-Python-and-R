# %% [markdown]
# # Import Modules

# %%
# Modules for web scraping
import requests
from bs4 import BeautifulSoup
# Module for data manipulation
import pandas as pd
# Module for regular expression
import re
# Module for file management
import os

# %% [markdown]
# # Web Scraping

# %% [markdown]
# **Current directory and URL**

# %%
url = 'https://www.premierleague.com/stats/top/players/goals'
main_url = 'https://www.premierleague.com/stats/top/players/'
dir_path = os.getcwd()

# %% [markdown]
# **Wrangling HTML with BeautifulSoup**

# %%
page = requests.get(url)
soup = BeautifulSoup(page.content,'html.parser')

# %% [markdown]
# **Get all dropdown list**

# %%
dropdown_list = soup.find_all('a',class_='topStatsLink',href=True)

# %%
sub_url = []
for elem in dropdown_list:
    sub_url.append(elem['href'])

# %%
print(sub_url)
# Out:
# ['goals', 'goal_assist', 'clean_sheet', 'appearances', 'mins_played', 'yellow_card', 'red_card', 'total_pass', 'touches', 'total_scoring_att', 'hit_woodwork', 'big_chance_missed', 'total_offside', 'total_tackle', 'fouls', 'dispossessed', 'own_goals', 'total_clearance', 'clearance_off_line', 'saves', 'penalty_save', 'total_high_claim', 'punches']

# %% [markdown]
# **Sample URL**

# %%
current_url = main_url + sub_url[0]
print(current_url)
# Out:
# https://www.premierleague.com/stats/top/players/goals

# %%
current_page = requests.get(current_url)
current_soup = BeautifulSoup(current_page.content,'html.parser')

# %%
current_soup.find_all('div',attrs={'data-script':'pl_stats'})
# Out:
# [<div class="statsCentreMenu" data-script="pl_stats" data-widget="stats-centre-menu">
#  <div class="current" tabindex="0"></div>
#  <ul class="sideNavLinks" role="menu">
#  <li> <a class="navLink" data-stripped-url="/stats" href="/stats" role="menuitem" target="_self">
#  <span>Dashboard</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  <li> <a class="navLink" data-stripped-url="/stats/top/players/goals?se=274" href="/stats/top/players/goals?se=274" role="menuitem" target="_self">
#  <span>Player Stats</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  <li> <a class="navLink" data-stripped-url="/stats/top/clubs/wins?se=274" href="/stats/top/clubs/wins?se=274" role="menuitem" target="_self">
#  <span>Club Stats</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  <li> <a class="navLink" data-stripped-url="/stats/all-time" href="/stats/all-time" role="menuitem" target="_self">
#  <span>All-time Stats</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  <li> <a class="navLink" data-stripped-url="/stats/records" href="/stats/records" role="menuitem" target="_self">
#  <span>Records</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  <li> <a class="navLink" data-stripped-url="/stats/head-to-head" href="/stats/head-to-head" role="menuitem" target="_self">
#  <span>Head-to-Head</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  <li> <a class="navLink" data-stripped-url="/stats/player-comparison" href="/stats/player-comparison" role="menuitem" target="_self">
#  <span>Player Comparison</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  <li> <a class="navLink" data-stripped-url="/stats/awards" href="/stats/awards" role="menuitem" target="_self">
#  <span>Awards</span>
#  <span class="icn chevron-rightwhite-small"></span>
#  </a>
#  </li>
#  </ul>
#  </div>,
#  <div data-comps="1" data-current-size="20" data-num-entries="2372" data-page="0" data-page-size="20" data-script="pl_stats" data-stat="goals" data-type="player" data-widget="stats-table">
#  <div class="dropDown noLabel open topStatsFilterDropdown">
#  <div class="current currentStatContainer" data-metric="goals">Goals</div>
#  <ul class="dropdownList" role="listbox">
#  <li>
#  <a class="topStatsLink" href="goals" role="option">
#  						Goals
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="goal_assist" role="option">
#  						Assists
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="clean_sheet" role="option">
#  						Clean sheets
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="appearances" role="option">
#  						Appearances
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="mins_played" role="option">
#  						Minutes played
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="yellow_card" role="option">
#  						Yellow cards
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="red_card" role="option">
#  						Red cards
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="total_pass" role="option">
#  						Passes
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="touches" role="option">
#  						Touches
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="total_scoring_att" role="option">
#  						Shots
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="hit_woodwork" role="option">
#  						Hit woodwork
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="big_chance_missed" role="option">
#  						Big chances missed
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="total_offside" role="option">
#  						Offsides
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="total_tackle" role="option">
#  						Tackles
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="fouls" role="option">
#  						Fouls
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="dispossessed" role="option">
#  						Dispossessed
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="own_goals" role="option">
#  						Own goals
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="total_clearance" role="option">
#  						Clearances
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="clearance_off_line" role="option">
#  						Clearances off line
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="saves" role="option">
#  						Saves
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="penalty_save" role="option">
#  						Penalties saved
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="total_high_claim" role="option">
#  						High claims
#  					</a>
#  </li>
#  <li>
#  <a class="topStatsLink" href="punches" role="option">
#  						Punches
#  					</a>
#  </li>
#  </ul>
#  </div>
#  <section class="pageFilter col-12" data-filter-config="rankedstats" data-reset-available="true"></section>
#  <div class="table statsTable">
#  <table>
#  <summary class="visuallyHidden">This table ranks players based on the currently selected stat type</summary>
#  <thead>
#  <tr>
#  <th class="rank" scope="col">Rank</th>
#  <th scope="col">Player</th>
#  <th class="hide-s" scope="col">Club</th>
#  <th class="hide-s" scope="col">Nationality</th>
#  <th class="mainStat" scope="col">Stat
#              <span class="reorderStatsButton">
#  <span class="icn sort"></span>
#  </span>
#  </th>
#  </tr>
#  </thead>
#  <tbody class="statsTableContainer">
#  <tr class="">
#  <td class="rank"><strong>1</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/89/Alan-Shearer/overview">
#  <strong>Alan Shearer</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">260</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>2</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/2064/Wayne-Rooney/overview">
#  <strong>Wayne Rooney</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">208</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>3</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/725/Andrew-Cole/overview">
#  <strong>Andrew Cole</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">187</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>4</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/4328/Sergio-Agüero/overview">
#  <strong>Sergio Agüero</strong></a>
#  </td>
#  <td class="hide-s">
#  <a class="statNameSecondary" href="/clubs/11/Manchester-City/overview">
#  <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
#  <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/25/p37572@x2.png 2x">
#  </img></span>
#  			Manchester City
#          </a>
#  </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag AR"></span>
#  <span class="playerCountry">Argentina</span>
#  </div>
#  </td>
#  <td class="mainStat">180</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>5</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/800/Frank-Lampard/overview">
#  <strong>Frank Lampard</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">177</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>6</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/1659/Thierry-Henry/overview">
#  <strong>Thierry Henry</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag FR"></span>
#  <span class="playerCountry">France</span>
#  </div>
#  </td>
#  <td class="mainStat">175</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>7</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/277/Robbie-Fowler/overview">
#  <strong>Robbie Fowler</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">163</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>8</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/1526/Jermain-Defoe/overview">
#  <strong>Jermain Defoe</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">162</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>9</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/1208/Michael-Owen/overview">
#  <strong>Michael Owen</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">150</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>10</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/462/Les-Ferdinand/overview">
#  <strong>Les Ferdinand</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">149</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>11</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/576/Teddy-Sheringham/overview">
#  <strong>Teddy Sheringham</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">146</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>12</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/2616/Robin-van-Persie/overview">
#  <strong>Robin van Persie</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag NL"></span>
#  <span class="playerCountry">Netherlands</span>
#  </div>
#  </td>
#  <td class="mainStat">144</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>13</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/3960/Harry-Kane/overview">
#  <strong>Harry Kane</strong></a>
#  </td>
#  <td class="hide-s">
#  <a class="statNameSecondary" href="/clubs/21/Tottenham-Hotspur/overview">
#  <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
#  <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/25/p78830@x2.png 2x">
#  </img></span>
#  			Tottenham Hotspur
#          </a>
#  </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">137</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>14</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/1413/Jimmy-Floyd-Hasselbaink/overview">
#  <strong>Jimmy Floyd Hasselbaink</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag NL"></span>
#  <span class="playerCountry">Netherlands</span>
#  </div>
#  </td>
#  <td class="mainStat">127</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>15</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/1692/Robbie-Keane/overview">
#  <strong>Robbie Keane</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag IE"></span>
#  <span class="playerCountry">Ireland</span>
#  </div>
#  </td>
#  <td class="mainStat">126</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>16</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/1135/Nicolas-Anelka/overview">
#  <strong>Nicolas Anelka</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag FR"></span>
#  <span class="playerCountry">France</span>
#  </div>
#  </td>
#  <td class="mainStat">125</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>17</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/59/Dwight-Yorke/overview">
#  <strong>Dwight Yorke</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag TT"></span>
#  <span class="playerCountry">Trinidad And Tobago</span>
#  </div>
#  </td>
#  <td class="mainStat">123</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>18</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/1575/Steven-Gerrard/overview">
#  <strong>Steven Gerrard</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">120</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>19</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/4290/Romelu-Lukaku/overview">
#  <strong>Romelu Lukaku</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag BE"></span>
#  <span class="playerCountry">Belgium</span>
#  </div>
#  </td>
#  <td class="mainStat">113</td>
#  </tr>
#  <tr class="">
#  <td class="rank"><strong>19</strong></td>
#  <td scopr="row">
#  <a class="playerName" href="/players/29/Ian-Wright/overview">
#  <strong>Ian Wright</strong></a>
#  </td>
#  <td class="hide-s">
#        -
#      </td>
#  <td class="hide-s">
#  <div class="info">
#  <span class="flag GB-ENG"></span>
#  <span class="playerCountry">England</span>
#  </div>
#  </td>
#  <td class="mainStat">113</td>
#  </tr>
#  </tbody>
#  </table>
#  </div>
#  <div class="paginationContainer right"></div>
#  </div>]

# %%
div.dropDown.noLabel.topStatsFilterDropdown
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-9bd137aeae4d> in <module>
# ----> 1 div.dropDown.noLabel.topStatsFilterDropdown
#
# NameError: name 'div' is not defined

# %%
current_soup.('//*[@id="mainContent"]/div[2]/div/div[2]/div[1]/section/div[1]/ul')
# Out:
# []

# %%
,attrs={'data-dropdown-list':'FOOTBALL_COMPSEASON'} ,class_='dd-FOOTBALL_COMPSEASON'
