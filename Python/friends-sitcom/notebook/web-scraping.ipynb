# %% [markdown]
# # Web scraping of `F.R.I.E.N.D.S.` Sinetron Comedy

# %% [markdown]
# ---

# %% [markdown]
# For introduction of Selenium, please be kind to open [**this site**](https://www.scrapingbee.com/blog/selenium-python/)
# Data source: [**fangj blog**](https://fangj.github.io/friends/)

# %% [markdown]
# ## Import modules

# %% [markdown]
# `%pip freeze > requirements.txt`

# %%
# Web scraping
from selenium import webdriver

# Data manipulation
import pandas as pd

# Regular expression
import re
import string

# File management
from pathlib import Path

# Parse JSON
import json

# %% [markdown]
# ## Load the Chromedriver

# %% [markdown]
# Read how to download webdriver for Chrome [**here**]('https://chromedriver.chromium.org/downloads')

# %%
# Open the driver
DRIVER_PATH = '../bin/chromedriver'
driver = webdriver.Chrome(executable_path = DRIVER_PATH)

# %% [markdown]
# ## Access the url

# %%
# Main url
url = 'https://fangj.github.io/friends/'

# %%
# Access to main url
driver.get(url)

# %% [markdown]
# ## Core Procedure

# %% [markdown]
# ### 1 Get URLs for episodes in seasons

# %%
# List of season name
list_season = [element.text for element in driver.find_elements_by_tag_name('h3')]

# %%
# Dictionary with blank list
dict_season = {key: [] for key in list_season}

# %%
dict_season
# Out:
# {'SEASON 1': [],
#  'SEASON 2': [],
#  'SEASON 3': [],
#  'SEASON 4': [],
#  'SEASON 5': [],
#  'SEASON 6': [],
#  'SEASON 7': [],
#  'SEASON 8': [],
#  'SEASON 9': [],
#  'SEASON 10': []}

# %%
# Loop each season
for i in range(len(dict_season)):
    # Elements in each season
    episodes = driver.find_elements_by_tag_name('ul')[i].find_elements_by_tag_name('a')
    
    # Loop the episodes in season
    for j in range(len(episodes)):
        # Get episode name and url
        dict_episode = {
            'title': episodes[j].text,
            'url': episodes[j].get_attribute('href')
        }
        
        # Dictionary key
        dict_key = list(dict_season.keys())[i]
        
        # Appen the urls
        dict_season[dict_key].append(dict_episode)

# %%
# Show the dictionary
dict_season
# Out:
# {'SEASON 1': [{'title': '101 Monica Gets A Roommate',
#    'url': 'https://fangj.github.io/friends/season/0101.html'},
#   {'title': '102 The Sonogram At The End',
#    'url': 'https://fangj.github.io/friends/season/0102.html'},
#   {'title': '103 The Thumb',
#    'url': 'https://fangj.github.io/friends/season/0103.html'},
#   {'title': '104 George Stephanopoulos',
#    'url': 'https://fangj.github.io/friends/season/0104.html'},
#   {'title': '105 The East German Laundry Detergent',
#    'url': 'https://fangj.github.io/friends/season/0105.html'},
#   {'title': '106 The Butt',
#    'url': 'https://fangj.github.io/friends/season/0106.html'},
#   {'title': '107 The Blackout',
#    'url': 'https://fangj.github.io/friends/season/0107.html'},
#   {'title': '108 Nana Dies Twice',
#    'url': 'https://fangj.github.io/friends/season/0108.html'},
#   {'title': '109 Underdog Gets Away',
#    'url': 'https://fangj.github.io/friends/season/0109.html'},
#   {'title': '110 The Monkey',
#    'url': 'https://fangj.github.io/friends/season/0110.html'},
#   {'title': '111 Mrs. Bing',
#    'url': 'https://fangj.github.io/friends/season/0111.html'},
#   {'title': '112 The Dozen Lasagnas',
#    'url': 'https://fangj.github.io/friends/season/0112.html'},
#   {'title': '113 The Boobies',
#    'url': 'https://fangj.github.io/friends/season/0113.html'},
#   {'title': '114 The Candy Hearts',
#    'url': 'https://fangj.github.io/friends/season/0114.html'},
#   {'title': '115 The Stoned Guy',
#    'url': 'https://fangj.github.io/friends/season/0115.html'},
#   {'title': '116 The Two Parts, Part I',
#    'url': 'https://fangj.github.io/friends/season/0116.html'},
#   {'title': '117 The Two Parts, Part II',
#    'url': 'https://fangj.github.io/friends/season/0117.html'},
#   {'title': '118 All The Poker',
#    'url': 'https://fangj.github.io/friends/season/0118.html'},
#   {'title': '119 The Monkey Gets Away',
#    'url': 'https://fangj.github.io/friends/season/0119.html'},
#   {'title': '120 The Evil Orthodontist',
#    'url': 'https://fangj.github.io/friends/season/0120.html'},
#   {'title': '121 The Fake Monica',
#    'url': 'https://fangj.github.io/friends/season/0121.html'},
#   {'title': '122 The Ick Factor',
#    'url': 'https://fangj.github.io/friends/season/0122.html'},
#   {'title': '123 The Birth',
#    'url': 'https://fangj.github.io/friends/season/0123.html'},
#   {'title': '124 Rachel Finds Out',
#    'url': 'https://fangj.github.io/friends/season/0124.html'}],
#  'SEASON 2': [{'title': "201 Ross's New Girlfriend",
#    'url': 'https://fangj.github.io/friends/season/0201.html'},
#   {'title': '202 The Breast Milk',
#    'url': 'https://fangj.github.io/friends/season/0202.html'},
#   {'title': '203 Heckles Dies',
#    'url': 'https://fangj.github.io/friends/season/0203.html'},
#   {'title': "204 Phoebe's Husband",
#    'url': 'https://fangj.github.io/friends/season/0204.html'},
#   {'title': '205 Five Steaks And An Eggplant',
#    'url': 'https://fangj.github.io/friends/season/0205.html'},
#   {'title': '206 The Baby On The Bus',
#    'url': 'https://fangj.github.io/friends/season/0206.html'},
#   {'title': '207 Ross Finds Out',
#    'url': 'https://fangj.github.io/friends/season/0207.html'},
#   {'title': '208 The List',
#    'url': 'https://fangj.github.io/friends/season/0208.html'},
#   {'title': "209 Phoebe's Dad",
#    'url': 'https://fangj.github.io/friends/season/0209.html'},
#   {'title': '210 Russ',
#    'url': 'https://fangj.github.io/friends/season/0210.html'},
#   {'title': '211 The Lesbian Wedding',
#    'url': 'https://fangj.github.io/friends/season/0211.html'},
#   {'title': '212-213 The Superbowl',
#    'url': 'https://fangj.github.io/friends/season/0212-0213.html'},
#   {'title': '214 The Prom Video',
#    'url': 'https://fangj.github.io/friends/season/0214.html'},
#   {'title': '215 Ross And Rachel... You Know',
#    'url': 'https://fangj.github.io/friends/season/0215.html'},
#   {'title': '216 Joey Moves Out',
#    'url': 'https://fangj.github.io/friends/season/0216.html'},
#   {'title': '217 Eddie Moves In',
#    'url': 'https://fangj.github.io/friends/season/0217.html'},
#   {'title': '218 Dr. Ramoray Dies',
#    'url': 'https://fangj.github.io/friends/season/0218.html'},
#   {'title': "219 Eddie Won't Go",
#    'url': 'https://fangj.github.io/friends/season/0219.html'},
#   {'title': '220 uld Yeller Dies',
#    'url': 'https://fangj.github.io/friends/season/0220.html'},
#   {'title': '221 The Bullies',
#    'url': 'https://fangj.github.io/friends/season/0221.html'},
#   {'title': '222 The Two Parties',
#    'url': 'https://fangj.github.io/friends/season/0222.html'},
#   {'title': '223 The Chicken Pox',
#    'url': 'https://fangj.github.io/friends/season/0223.html'},
#   {'title': "224 Barry And Mindy's Wedding",
#    'url': 'https://fangj.github.io/friends/season/0224.html'}],
#  'SEASON 3': [{'title': '301 The Princess Leia Fantasy',
#    'url': 'https://fangj.github.io/friends/season/0301.html'},
#   {'title': "302 No One's Ready",
#    'url': 'https://fangj.github.io/friends/season/0302.html'},
#   {'title': '303 The Jam',
#    'url': 'https://fangj.github.io/friends/season/0303.html'},
#   {'title': '304 The Metaphorical Tunnel',
#    'url': 'https://fangj.github.io/friends/season/0304.html'},
#   {'title': '305 Frank Jr.',
#    'url': 'https://fangj.github.io/friends/season/0305.html'},
#   {'title': '306 The Flashback',
#    'url': 'https://fangj.github.io/friends/season/0306.html'},
#   {'title': '307 The Race Car Bed',
#    'url': 'https://fangj.github.io/friends/season/0307.html'},
#   {'title': '308 The Giant Poking Device',
#    'url': 'https://fangj.github.io/friends/season/0308.html'},
#   {'title': '309 The Football',
#    'url': 'https://fangj.github.io/friends/season/0309.html'},
#   {'title': '310 Rachel Quits',
#    'url': 'https://fangj.github.io/friends/season/0310.html'},
#   {'title': "311 Chandler Can't Remember Which Sister",
#    'url': 'https://fangj.github.io/friends/season/0311.html'},
#   {'title': '312 All The Jealousy',
#    'url': 'https://fangj.github.io/friends/season/0312.html'},
#   {'title': '313 Monica And Richard Are Just Friends',
#    'url': 'https://fangj.github.io/friends/season/0313.html'},
#   {'title': "314 Phoebe's Ex-Partner",
#    'url': 'https://fangj.github.io/friends/season/0314.html'},
#   {'title': '315 Ross And Rachel Take A Break',
#    'url': 'https://fangj.github.io/friends/season/0315.html'},
#   {'title': '316 The Morning After',
#    'url': 'https://fangj.github.io/friends/season/0316.html'},
#   {'title': '317 The Ski Trip',
#    'url': 'https://fangj.github.io/friends/season/0317.html'},
#   {'title': '318 The Hypnosis Tape',
#    'url': 'https://fangj.github.io/friends/season/0318.html'},
#   {'title': '319 The Tiny T-Shirt',
#    'url': 'https://fangj.github.io/friends/season/0319.html'},
#   {'title': '320 The Dullhouse',
#    'url': 'https://fangj.github.io/friends/season/0320.html'},
#   {'title': '321 The Chick And The Duck',
#    'url': 'https://fangj.github.io/friends/season/0321.html'},
#   {'title': '322 The Screamer',
#    'url': 'https://fangj.github.io/friends/season/0322.html'},
#   {'title': "323 Ross's Thing",
#    'url': 'https://fangj.github.io/friends/season/0323.html'},
#   {'title': '324 The Ultimate Fighting Champion',
#    'url': 'https://fangj.github.io/friends/season/0324.html'},
#   {'title': '325 At The Beach',
#    'url': 'https://fangj.github.io/friends/season/0325.html'}],
#  'SEASON 4': [{'title': '401 The Jellyfish',
#    'url': 'https://fangj.github.io/friends/season/0401.html'},
#   {'title': '402 The Cat',
#    'url': 'https://fangj.github.io/friends/season/0402.html'},
#   {'title': '403 The Cuffs',
#    'url': 'https://fangj.github.io/friends/season/0403.html'},
#   {'title': '404 The Ballroom Dancing',
#    'url': 'https://fangj.github.io/friends/season/0404.html'},
#   {'title': "405 Joey's New Girlfriend",
#    'url': 'https://fangj.github.io/friends/season/0405.html'},
#   {'title': '406 The Dirty Girl',
#    'url': 'https://fangj.github.io/friends/season/0406.html'},
#   {'title': '407 Chandler Crosses The Line',
#    'url': 'https://fangj.github.io/friends/season/0407.html'},
#   {'title': '408 Chandler In A Box',
#    'url': 'https://fangj.github.io/friends/season/0408.html'},
#   {'title': "409 They're Going To Party",
#    'url': 'https://fangj.github.io/friends/season/0409.html'},
#   {'title': '410 The Girl From Poughkeepsie',
#    'url': 'https://fangj.github.io/friends/season/0410.html'},
#   {'title': "411 Phoebe's Uterus",
#    'url': 'https://fangj.github.io/friends/season/0411.html'},
#   {'title': '412 The Embryos',
#    'url': 'https://fangj.github.io/friends/season/0412.html'},
#   {'title': "413 Rachel's Crush",
#    'url': 'https://fangj.github.io/friends/season/0413.html'},
#   {'title': "414 Joey's Dirty Day",
#    'url': 'https://fangj.github.io/friends/season/0414.html'},
#   {'title': '415 All The Rugby',
#    'url': 'https://fangj.github.io/friends/season/0415.html'},
#   {'title': '416 The Fake Party',
#    'url': 'https://fangj.github.io/friends/season/0416.html'},
#   {'title': '417 The Free Porn',
#    'url': 'https://fangj.github.io/friends/season/0417.html'},
#   {'title': "418 Rachel's New Dress",
#    'url': 'https://fangj.github.io/friends/season/0418.html'},
#   {'title': '419 All The Haste',
#    'url': 'https://fangj.github.io/friends/season/0419.html'},
#   {'title': '420 The Wedding Dresses',
#    'url': 'https://fangj.github.io/friends/season/0420.html'},
#   {'title': '421 The Invitation',
#    'url': 'https://fangj.github.io/friends/season/0421.html'},
#   {'title': '422 The Worst Best Man Ever',
#    'url': 'https://fangj.github.io/friends/season/0422.html'},
#   {'title': "423 Ross's Wedding",
#    'url': 'https://fangj.github.io/friends/season/0423.html'}],
#  'SEASON 5': [{'title': '501 Ross Says Rachel',
#    'url': 'https://fangj.github.io/friends/season/0501.html'},
#   {'title': '502 All The Kissing',
#    'url': 'https://fangj.github.io/friends/season/0502.html'},
#   {'title': '503 Hundredth',
#    'url': 'https://fangj.github.io/friends/season/0503.html'},
#   {'title': '504 Phoebe Hates PBS',
#    'url': 'https://fangj.github.io/friends/season/0504.html'},
#   {'title': '505 The Kips',
#    'url': 'https://fangj.github.io/friends/season/0505.html'},
#   {'title': '506 The Yeti',
#    'url': 'https://fangj.github.io/friends/season/0506.html'},
#   {'title': '507 Ross Moves In',
#    'url': 'https://fangj.github.io/friends/season/0507.html'},
#   {'title': '508 The Thanksgiving Flashbacks',
#    'url': 'https://fangj.github.io/friends/season/0508.html'},
#   {'title': "509 Ross's Sandwich",
#    'url': 'https://fangj.github.io/friends/season/0509.html'},
#   {'title': '510 The Inappropriate Sister',
#    'url': 'https://fangj.github.io/friends/season/0510.html'},
#   {'title': '511 All The Resulutions',
#    'url': 'https://fangj.github.io/friends/season/0511.html'},
#   {'title': "512 Chandler's Work Laugh",
#    'url': 'https://fangj.github.io/friends/season/0512.html'},
#   {'title': "513 Joey's Bag",
#    'url': 'https://fangj.github.io/friends/season/0513.html'},
#   {'title': '514 Everybody Finds Out',
#    'url': 'https://fangj.github.io/friends/season/0514.html'},
#   {'title': '515 The Girl Who Hits Joey',
#    'url': 'https://fangj.github.io/friends/season/0515.html'},
#   {'title': '516 The Cop',
#    'url': 'https://fangj.github.io/friends/season/0516.html'},
#   {'title': "517 Rachel's Inadvertant Kiss",
#    'url': 'https://fangj.github.io/friends/season/0517.html'},
#   {'title': '518 Rachel Smokes',
#    'url': 'https://fangj.github.io/friends/season/0518.html'},
#   {'title': "519 Ross Can't Flirt",
#    'url': 'https://fangj.github.io/friends/season/0519.html'},
#   {'title': '520 The Ride Along',
#    'url': 'https://fangj.github.io/friends/season/0520.html'},
#   {'title': '521 The Ball',
#    'url': 'https://fangj.github.io/friends/season/0521.html'},
#   {'title': "522 Joey's Big Break",
#    'url': 'https://fangj.github.io/friends/season/0522.html'},
#   {'title': '523 In Vegas',
#    'url': 'https://fangj.github.io/friends/season/0523.html'}],
#  'SEASON 6': [{'title': '601 Vegas',
#    'url': 'https://fangj.github.io/friends/season/0601.html'},
#   {'title': '602 Ross Hugs Rachel',
#    'url': 'https://fangj.github.io/friends/season/0602.html'},
#   {'title': "603 Ross's Denial",
#    'url': 'https://fangj.github.io/friends/season/0603.html'},
#   {'title': '604 Joey Loses His Insurance',
#    'url': 'https://fangj.github.io/friends/season/0604.html'},
#   {'title': "605 Joey's Porsche",
#    'url': 'https://fangj.github.io/friends/season/0605.html'},
#   {'title': '606 On The Last Night',
#    'url': 'https://fangj.github.io/friends/season/0606.html'},
#   {'title': '607 Phoebe Runs',
#    'url': 'https://fangj.github.io/friends/season/0607.html'},
#   {'title': "608 Ross's Teeth",
#    'url': 'https://fangj.github.io/friends/season/0608.html'},
#   {'title': '609 Ross Got High',
#    'url': 'https://fangj.github.io/friends/season/0609.html'},
#   {'title': '610 The Routine',
#    'url': 'https://fangj.github.io/friends/season/0610.html'},
#   {'title': '611 The Apothecary Table',
#    'url': 'https://fangj.github.io/friends/season/0611.html'},
#   {'title': '612 The Joke',
#    'url': 'https://fangj.github.io/friends/season/0612.html'},
#   {'title': "613 Rachel's Sister",
#    'url': 'https://fangj.github.io/friends/season/0613.html'},
#   {'title': "614 Chandler Can't Cry",
#    'url': 'https://fangj.github.io/friends/season/0614.html'},
#   {'title': '615-616 That Could Have Been, Part I & II',
#    'url': 'https://fangj.github.io/friends/season/0615-0616.html'},
#   {'title': '617 Unagi',
#    'url': 'https://fangj.github.io/friends/season/0617.html'},
#   {'title': '618 Ross Dates A Student',
#    'url': 'https://fangj.github.io/friends/season/0618.html'},
#   {'title': "619 Joey's Fridge",
#    'url': 'https://fangj.github.io/friends/season/0619.html'},
#   {'title': '620 Mac And C.H.E.E.S.E.',
#    'url': 'https://fangj.github.io/friends/season/0620.html'},
#   {'title': "621 Ross Meets Elizabeth's Dad",
#    'url': 'https://fangj.github.io/friends/season/0621.html'},
#   {'title': "622 Paul's The Man",
#    'url': 'https://fangj.github.io/friends/season/0622.html'},
#   {'title': '623 The Ring',
#    'url': 'https://fangj.github.io/friends/season/0623.html'},
#   {'title': '624 The Proposal, Part I & II',
#    'url': 'https://fangj.github.io/friends/season/0624.html'}],
#  'SEASON 7': [{'title': "701 Monica's Thunder",
#    'url': 'https://fangj.github.io/friends/season/0701.html'},
#   {'title': "702 Rachel's Book",
#    'url': 'https://fangj.github.io/friends/season/0702.html'},
#   {'title': "703 Phoebe's Cookies",
#    'url': 'https://fangj.github.io/friends/season/0703.html'},
#   {'title': "704 Rachel's Assistant",
#    'url': 'https://fangj.github.io/friends/season/0704.html'},
#   {'title': '705 The Engagement Picture',
#    'url': 'https://fangj.github.io/friends/season/0705.html'},
#   {'title': '706 The Nap Partners',
#    'url': 'https://fangj.github.io/friends/season/0706.html'},
#   {'title': "707 Ross's Library Book",
#    'url': 'https://fangj.github.io/friends/season/0707.html'},
#   {'title': "708 Chandler Doesn't Like Dogs",
#    'url': 'https://fangj.github.io/friends/season/0708.html'},
#   {'title': '709 All The Candy',
#    'url': 'https://fangj.github.io/friends/season/0709.html'},
#   {'title': '710 The Huliday Armadillo',
#    'url': 'https://fangj.github.io/friends/season/0710.html'},
#   {'title': '711 All The Cheesecakes',
#    'url': 'https://fangj.github.io/friends/season/0711.html'},
#   {'title': "712 They're Up All Night",
#    'url': 'https://fangj.github.io/friends/season/0712.html'},
#   {'title': '713 Rosita Dies',
#    'url': 'https://fangj.github.io/friends/season/0713.html'},
#   {'title': '714 They All Turn Thirty',
#    'url': 'https://fangj.github.io/friends/season/0714.html'},
#   {'title': "715 Joey's New Brain",
#    'url': 'https://fangj.github.io/friends/season/0715.html'},
#   {'title': '716 The Truth About London',
#    'url': 'https://fangj.github.io/friends/season/0716.html'},
#   {'title': '717 The Cheap Wedding Dress',
#    'url': 'https://fangj.github.io/friends/season/0717.html'},
#   {'title': "718 Joey's Award",
#    'url': 'https://fangj.github.io/friends/season/0718.html'},
#   {'title': "719 Ross And Monica's Cousin",
#    'url': 'https://fangj.github.io/friends/season/0719.html'},
#   {'title': "720 Rachel's Big Kiss",
#    'url': 'https://fangj.github.io/friends/season/0720.html'},
#   {'title': '721 The Vows',
#    'url': 'https://fangj.github.io/friends/season/0721.html'},
#   {'title': "722 Chandler's Dad",
#    'url': 'https://fangj.github.io/friends/season/0722.html'},
#   {'title': "723 Chandler And Monica's Wedding",
#    'url': 'https://fangj.github.io/friends/season/0723.html'},
#   {'title': "724 outtakesFriends Special: The Stuff You've Never Seen",
#    'url': 'https://fangj.github.io/friends/season/07outtakes.html'}],
#  'SEASON 8': [{'title': '801 "I Do"',
#    'url': 'https://fangj.github.io/friends/season/0801.html'},
#   {'title': '802 The Red Sweater',
#    'url': 'https://fangj.github.io/friends/season/0802.html'},
#   {'title': '803 Rachel Tells...',
#    'url': 'https://fangj.github.io/friends/season/0803.html'},
#   {'title': '804 The Videotape',
#    'url': 'https://fangj.github.io/friends/season/0804.html'},
#   {'title': "805 Rachel's Date",
#    'url': 'https://fangj.github.io/friends/season/0805.html'},
#   {'title': '806 The Halloween Party',
#    'url': 'https://fangj.github.io/friends/season/0806.html'},
#   {'title': '807 The Stain',
#    'url': 'https://fangj.github.io/friends/season/0807.html'},
#   {'title': '808 The Stripper',
#    'url': 'https://fangj.github.io/friends/season/0808.html'},
#   {'title': '809 The Rumor',
#    'url': 'https://fangj.github.io/friends/season/0809.html'},
#   {'title': "810 Monica's Boots",
#    'url': 'https://fangj.github.io/friends/season/0810.html'},
#   {'title': "811 Ross's Step Forward",
#    'url': 'https://fangj.github.io/friends/season/0811.html'},
#   {'title': '812 Joey Dates Rachel',
#    'url': 'https://fangj.github.io/friends/season/0812.html'},
#   {'title': '813 Chandler Takes A Bath',
#    'url': 'https://fangj.github.io/friends/season/0813.html'},
#   {'title': '814 The Secret Closet',
#    'url': 'https://fangj.github.io/friends/season/0814.html'},
#   {'title': '815 The Birthing Video',
#    'url': 'https://fangj.github.io/friends/season/0815.html'},
#   {'title': '816 Joey Tells Rachel',
#    'url': 'https://fangj.github.io/friends/season/0816.html'},
#   {'title': '817 The Tea Leaves',
#    'url': 'https://fangj.github.io/friends/season/0817.html'},
#   {'title': '818 In Massapequa',
#    'url': 'https://fangj.github.io/friends/season/0818.html'},
#   {'title': "819 Joey's Interview",
#    'url': 'https://fangj.github.io/friends/season/0819.html'},
#   {'title': '820 The Baby Shower',
#    'url': 'https://fangj.github.io/friends/season/0820.html'},
#   {'title': '821 The Cooking Class',
#    'url': 'https://fangj.github.io/friends/season/0821.html'},
#   {'title': '822 Rachel Is Late',
#    'url': 'https://fangj.github.io/friends/season/0822.html'},
#   {'title': '823 Rachel Has A Baby',
#    'url': 'https://fangj.github.io/friends/season/0823.html'}],
#  'SEASON 9': [{'title': '901 No One Proposes',
#    'url': 'https://fangj.github.io/friends/season/0901.html'},
#   {'title': '902 Emma Cries',
#    'url': 'https://fangj.github.io/friends/season/0902.html'},
#   {'title': '903 The Pediatrician',
#    'url': 'https://fangj.github.io/friends/season/0903.html'},
#   {'title': '904 The Sharks',
#    'url': 'https://fangj.github.io/friends/season/0904.html'},
#   {'title': "905 Phoebe's Birthday Dinner",
#    'url': 'https://fangj.github.io/friends/season/0905.html'},
#   {'title': '906 The Male Nanny',
#    'url': 'https://fangj.github.io/friends/season/0906.html'},
#   {'title': "907 Ross's Inappropriate Song",
#    'url': 'https://fangj.github.io/friends/season/0907.html'},
#   {'title': "908 Rachel's Other Sister",
#    'url': 'https://fangj.github.io/friends/season/0908.html'},
#   {'title': "909 Rachel's Phone Number",
#    'url': 'https://fangj.github.io/friends/season/0909.html'},
#   {'title': '910 Christmas In Tulsa',
#    'url': 'https://fangj.github.io/friends/season/0910.html'},
#   {'title': '911 Rachel Goes Back To Work',
#    'url': 'https://fangj.github.io/friends/season/0911.html'},
#   {'title': "912 Phoebe's Rats",
#    'url': 'https://fangj.github.io/friends/season/0912.html'},
#   {'title': '913 Monica Sings',
#    'url': 'https://fangj.github.io/friends/season/0913.html'},
#   {'title': '914 The Blind Dates',
#    'url': 'https://fangj.github.io/friends/season/0914.html'},
#   {'title': '915 The Mugging',
#    'url': 'https://fangj.github.io/friends/season/0915.html'},
#   {'title': '916 The Boob Job',
#    'url': 'https://fangj.github.io/friends/season/0916.html'},
#   {'title': '917 The Memorial Service',
#    'url': 'https://fangj.github.io/friends/season/0917.html'},
#   {'title': '918 The Lottery',
#    'url': 'https://fangj.github.io/friends/season/0918.html'},
#   {'title': "919 Rachel's Dream",
#    'url': 'https://fangj.github.io/friends/season/0919.html'},
#   {'title': '920 The Soap Opera Party',
#    'url': 'https://fangj.github.io/friends/season/0920.html'},
#   {'title': '921 The Fertility Test',
#    'url': 'https://fangj.github.io/friends/season/0921.html'},
#   {'title': '922 The Donor',
#    'url': 'https://fangj.github.io/friends/season/0922.html'},
#   {'title': '923-924 In Barbados',
#    'url': 'https://fangj.github.io/friends/season/0923-0924.html'}],
#  'SEASON 10': [{'title': '1001 Joey and Rachel Kiss',
#    'url': 'https://fangj.github.io/friends/season/1001.html'},
#   {'title': '1002 Ross Is Fine',
#    'url': 'https://fangj.github.io/friends/season/1002.html'},
#   {'title': "1003 Ross's Tan",
#    'url': 'https://fangj.github.io/friends/season/1003.html'},
#   {'title': '1004 The Cake',
#    'url': 'https://fangj.github.io/friends/season/1004.html'},
#   {'title': "1005 Rachel's Sister Babysits",
#    'url': 'https://fangj.github.io/friends/season/1005.html'},
#   {'title': "1006 Ross's Grant",
#    'url': 'https://fangj.github.io/friends/season/1006.html'},
#   {'title': '1007 The Home Study',
#    'url': 'https://fangj.github.io/friends/season/1007.html'},
#   {'title': '1008 The Late Thanksgiving',
#    'url': 'https://fangj.github.io/friends/season/1008.html'},
#   {'title': '1009 The Birth Mother',
#    'url': 'https://fangj.github.io/friends/season/1009.html'},
#   {'title': '1010 Chandler Gets Caught',
#    'url': 'https://fangj.github.io/friends/season/1010.html'},
#   {'title': '1011 The Stripper Cries',
#    'url': 'https://fangj.github.io/friends/season/1011.html'},
#   {'title': "1012 Phoebe's Wedding",
#    'url': 'https://fangj.github.io/friends/season/1012.html'},
#   {'title': '1013 Joey Speaks French',
#    'url': 'https://fangj.github.io/friends/season/1013.html'},
#   {'title': '1014 Princess Consuela',
#    'url': 'https://fangj.github.io/friends/season/1014.html'},
#   {'title': '1015 Estelle Dies',
#    'url': 'https://fangj.github.io/friends/season/1015.html'},
#   {'title': "1016 Rachel's Going Away Party",
#    'url': 'https://fangj.github.io/friends/season/1016.html'},
#   {'title': '1017-1018 The Last One, Part I & II',
#    'url': 'https://fangj.github.io/friends/season/1017-1018.html'}]}

# %% [markdown]
# ### 2 Access one episode

# %%
# Selected season
selected_season = list(dict_season.keys())[0]
# Selected episode
selected_episode = dict_season[selected_season][0]
# URL episode
url_episode = selected_episode['url']

# %%
url_episode
# Out:
# 'https://fangj.github.io/friends/season/0101.html'

# %%
# Access to url
driver.get(url_episode)

# %% [markdown]
# ### 3 Get metadata in episode

# %%
# Metadata
raw_metadata = driver.find_element_by_tag_name('p').text
raw_metadata
# Out:
# 'Written by: Marta Kauffman & David Crane\nTranscribed by: guineapig\nAdditional transcribing by: Eric Aasen\n(Note: The previously unseen parts of this episode are shown in blue text.)'

# %%
# Written by
try:
    written_by = re.findall(pattern = 'Written by:\s*(.+)', string = raw_metadata)[0]
except:
    written_by = None

# Transcribed by
try:
    transcribed_by = re.findall(pattern = 'Transcribed by:\s*(.+)', string = raw_metadata)[0]
except:
    transcribed_by = None

# Transcribing by
try:
    transcribing_by = re.findall(pattern = 'Additional transcribing by:\s*(.+)', string = raw_metadata)[0]
except:
    transcribing_by = None

# Note
try:
    note = re.findall(pattern = '\\(?Note:\s*(.+)\\)$', string = raw_metadata)[0]
except:
    note = None

# %%
# Store the metadata
metadata = {
    'season': selected_season,
    'title': selected_episode['title'],
    'written_by': written_by,
    'transcribed_by': transcribed_by,
    'additional_transcribing_by': transcribing_by,
    'note': note
}

# %%
# Show the metadata
metadata
# Out:
# {'season': 'SEASON 1',
#  'title': '101 Monica Gets A Roommate',
#  'written_by': 'Marta Kauffman & David Crane',
#  'transcribed_by': 'guineapig',
#  'additional_transcribing_by': 'Eric Aasen',
#  'note': 'The previously unseen parts of this episode are shown in blue text.'}

# %% [markdown]
# ### 4 Get the dialog

# %%
# Get the dialog
l = driver.find_elements_by_tag_name('p')

# %%
# Create a empty list
list_ = []

# Dialog is not in standard format
if len(l) < 50:
    # Long text
    long_text = []
    
    # Check length of l
    if len(l) > 0 and len(l) != 1:
        # Loop
        for elem in l:
            if len(elem.text) > 50:
                # Get the long text dialog
                long_text_ = elem.text.split('\n')
                # Remove the multiple new lines
                long_text_ = list(filter(lambda x: x != '', long_text_))
                long_text += long_text_
    else:
        # Get the long text dialog
        long_text_ = driver.find_element_by_tag_name('html').text.split('\n')
        # Remove the multiple new lines
        long_text_ = list(filter(lambda x: x != '', long_text_))
        long_text += long_text_

    # Parameters
    stat_long = True
    stat = True
    i = 0
    j = 0

else:
    # Parameters
    stat_long = False
    stat = True
    i = 1
    j = 0

# Main loops
while stat:
    try:
        # String
        if stat_long:
            string_ = long_text[i]
        else:
            string_ = l[i].text
        # Scene play
        try:
            scene_play = re.search(pattern = '\\[Scene.+?[\\]|\\)]', string = string_)
            # String of scene
            scene_text = scene_play.group(0)
        except:
            scene_text = '[Scene: Beginning of Episode (Generated)]'
        # Status of scene
        stat_loop = bool(scene_play)

        # If first index is not scene description
        if not stat_loop and i == 1:
            stat_loop = True
            k = i
        else:
            # First increment
            k = i + 1

        # Dictionary for dialog
        dict_ = {
            'scene_no': j,
            'scene_mark': scene_text,
            'dialog': ''
        }

        # Secondary loops
        while stat_loop:
            try:
                # String
                if stat_long:
                    string_loop = long_text[k]
                else:
                    string_loop = l[k].text
                # Scene play
                scene_play_loop = re.search(pattern = '\\[Scene.+?[\\]|\\)]', string = string_loop)
                # Status of scene
                stat_loop = not bool(scene_play_loop)

                # Update the dialog in dictionary
                if stat_loop:
                    dict_['dialog'] += string_loop + '\n'
                    k += 1
                else:
                    # Scene within dialog
                    if len(string_loop) != len(scene_play_loop.group(0)):
                        string_loop_trunc = re.sub(pattern = '\\[Scene.+?[\\]|\\)]', string = string_loop, repl = '')
                        dict_['dialog'] += string_loop_trunc + '\n'
            except:
                # Stop secondary loop
                stat_loop = False

        # Append the scene in one episode
        list_.append(dict_)

        # Update parameters
        i = k
        j += 1

    except:
        # Stop main loop
        stat = False

# %%
# Number of scene in episode
len(list_)
# Out:
# 15

# %%
# Sample scene
list_[0]
# Out:
# {'scene_no': 0,
#  'scene_mark': '[Scene: Central Perk, Chandler, Joey, Phoebe, and Monica are there.]',
#  'dialog': 'Monica: There\'s nothing to tell! He\'s just some guy I work with!\nJoey: C\'mon, you\'re going out with the guy! There\'s gotta be something wrong with him!\nChandler: All right Joey, be nice.  So does he have a hump? A hump and a hairpiece?\nPhoebe: Wait, does he eat chalk?\n(They all stare, bemused.)\nPhoebe: Just, \'cause, I don\'t want her to go through what I went through with Carl- oh!\nMonica: Okay, everybody relax. This is not even a date. It\'s just two people going out to dinner and- not having sex.\nChandler: Sounds like a date to me.\n[Time Lapse]\nChandler: Alright, so I\'m back in high school, I\'m standing in the middle of the cafeteria, and I realize I am totally naked.\nAll: Oh, yeah. Had that dream.\nChandler: Then I look down, and I realize there\'s a phone... there.\nJoey: Instead of...?\nChandler: That\'s right.\nJoey: Never had that dream.\nPhoebe: No.\nChandler: All of a sudden, the phone starts to ring. Now I don\'t know what to do, everybody starts looking at me.\nMonica: And they weren\'t looking at you before?!\nChandler: Finally, I figure I\'d better answer it, and it turns out it\'s my mother, which is very-very weird, because- she never calls me!\n[Time Lapse, Ross has entered.]\nRoss: (mortified) Hi.\nJoey: This guy says hello, I wanna kill myself.\nMonica: Are you okay, sweetie?\nRoss: I just feel like someone reached down my throat, grabbed my small intestine, pulled it out of my mouth and tied it around my neck...\nChandler: Cookie?\nMonica: (explaining to the others) Carol moved her stuff out today.\nJoey: Ohh.\nMonica: (to Ross) Let me get you some coffee.\nRoss: Thanks.\nPhoebe: Ooh! Oh! (She starts to pluck at the air just in front of Ross.)\nRoss: No, no don\'t! Stop cleansing my aura! No, just leave my aura alone, okay?\nPhoebe: Fine!  Be murky!\nRoss: I\'ll be fine, alright? Really, everyone. I hope she\'ll be very happy.\nMonica: No you don\'t.\nRoss: No I don\'t, to hell with her, she left me!\nJoey: And you never knew she was a lesbian...\nRoss: No!! Okay?! Why does everyone keep fixating on that? She didn\'t know, how should I know?\nChandler: Sometimes I wish I was a lesbian... (They all stare at him.) Did I say that out loud?\nRoss: I told mom and dad last night, they seemed to take it pretty well.\nMonica: Oh really, so that hysterical phone call I got from a woman at sobbing 3:00 A.M., "I\'ll never have grandchildren, I\'ll never have grandchildren." was what?  A wrong number?\nRoss: Sorry.\nJoey: Alright Ross, look. You\'re feeling a lot of pain right now. You\'re angry. You\'re hurting. Can I tell you what the answer is?\n(Ross gestures his consent.)\nJoey: Strip joint! C\'mon, you\'re single! Have some hormones!\nRoss: I don\'t want to be single, okay? I just... I just- I just wanna be married again!\n(Rachel enters in a wet wedding dress and starts to search the room.)\nChandler: And I just want a million dollars! (He extends his hand hopefully.)\nMonica: Rachel?!\nRachel: Oh God Monica hi! Thank God! I just went to your building and you weren\'t there and then this guy with a big hammer said you might be here and you are, you are!\nWaitress: Can I get you some coffee?\nMonica: (pointing at Rachel) De-caff. (to All) Okay, everybody, this is Rachel, another Lincoln High survivor. (to Rachel) This is everybody, this is Chandler, and Phoebe, and Joey, and- you remember my brother Ross?\nRachel: Hi, sure!\nRoss: Hi.\n(They go to hug but Ross\'s umbrella opens.  He sits back down defeated again.  A moment of silence follows as Rachel sits and the others expect her to explain.)\nMonica: So you wanna tell us now, or are we waiting for four wet bridesmaids?\nRachel: Oh God... well, it started about a half hour before the wedding. I was in the room where we were keeping all the presents, and I was looking at this gravy boat. This really gorgeous Lamauge gravy boat. When all of a sudden- (to the waitress that brought her coffee)Sweet \'n\' Lo?- I realized that I was more  ...

# %% [markdown]
# ### 5 Merge metadata and dialog

# %%
# File for one episode
episode_ = {
    'metadata': metadata,
    'data': list_
}

# %%
# Show the file
episode_
# Out:
# {'metadata': {'season': 'SEASON 1',
#   'title': '101 Monica Gets A Roommate',
#   'written_by': 'Marta Kauffman & David Crane',
#   'transcribed_by': 'guineapig',
#   'additional_transcribing_by': 'Eric Aasen',
#   'note': 'The previously unseen parts of this episode are shown in blue text.'},
#  'data': [{'scene_no': 0,
#    'scene_mark': '[Scene: Central Perk, Chandler, Joey, Phoebe, and Monica are there.]',
#    'dialog': 'Monica: There\'s nothing to tell! He\'s just some guy I work with!\nJoey: C\'mon, you\'re going out with the guy! There\'s gotta be something wrong with him!\nChandler: All right Joey, be nice.  So does he have a hump? A hump and a hairpiece?\nPhoebe: Wait, does he eat chalk?\n(They all stare, bemused.)\nPhoebe: Just, \'cause, I don\'t want her to go through what I went through with Carl- oh!\nMonica: Okay, everybody relax. This is not even a date. It\'s just two people going out to dinner and- not having sex.\nChandler: Sounds like a date to me.\n[Time Lapse]\nChandler: Alright, so I\'m back in high school, I\'m standing in the middle of the cafeteria, and I realize I am totally naked.\nAll: Oh, yeah. Had that dream.\nChandler: Then I look down, and I realize there\'s a phone... there.\nJoey: Instead of...?\nChandler: That\'s right.\nJoey: Never had that dream.\nPhoebe: No.\nChandler: All of a sudden, the phone starts to ring. Now I don\'t know what to do, everybody starts looking at me.\nMonica: And they weren\'t looking at you before?!\nChandler: Finally, I figure I\'d better answer it, and it turns out it\'s my mother, which is very-very weird, because- she never calls me!\n[Time Lapse, Ross has entered.]\nRoss: (mortified) Hi.\nJoey: This guy says hello, I wanna kill myself.\nMonica: Are you okay, sweetie?\nRoss: I just feel like someone reached down my throat, grabbed my small intestine, pulled it out of my mouth and tied it around my neck...\nChandler: Cookie?\nMonica: (explaining to the others) Carol moved her stuff out today.\nJoey: Ohh.\nMonica: (to Ross) Let me get you some coffee.\nRoss: Thanks.\nPhoebe: Ooh! Oh! (She starts to pluck at the air just in front of Ross.)\nRoss: No, no don\'t! Stop cleansing my aura! No, just leave my aura alone, okay?\nPhoebe: Fine!  Be murky!\nRoss: I\'ll be fine, alright? Really, everyone. I hope she\'ll be very happy.\nMonica: No you don\'t.\nRoss: No I don\'t, to hell with her, she left me!\nJoey: And you never knew she was a lesbian...\nRoss: No!! Okay?! Why does everyone keep fixating on that? She didn\'t know, how should I know?\nChandler: Sometimes I wish I was a lesbian... (They all stare at him.) Did I say that out loud?\nRoss: I told mom and dad last night, they seemed to take it pretty well.\nMonica: Oh really, so that hysterical phone call I got from a woman at sobbing 3:00 A.M., "I\'ll never have grandchildren, I\'ll never have grandchildren." was what?  A wrong number?\nRoss: Sorry.\nJoey: Alright Ross, look. You\'re feeling a lot of pain right now. You\'re angry. You\'re hurting. Can I tell you what the answer is?\n(Ross gestures his consent.)\nJoey: Strip joint! C\'mon, you\'re single! Have some hormones!\nRoss: I don\'t want to be single, okay? I just... I just- I just wanna be married again!\n(Rachel enters in a wet wedding dress and starts to search the room.)\nChandler: And I just want a million dollars! (He extends his hand hopefully.)\nMonica: Rachel?!\nRachel: Oh God Monica hi! Thank God! I just went to your building and you weren\'t there and then this guy with a big hammer said you might be here and you are, you are!\nWaitress: Can I get you some coffee?\nMonica: (pointing at Rachel) De-caff. (to All) Okay, everybody, this is Rachel, another Lincoln High survivor. (to Rachel) This is everybody, this is Chandler, and Phoebe, and Joey, and- you remember my brother Ross?\nRachel: Hi, sure!\nRoss: Hi.\n(They go to hug but Ross\'s umbrella opens.  He sits back down defeated again.  A moment of silence follows as Rachel sits and the others expect her to explain.)\nMonica: So you wanna tell us now, or are we waiting for four wet bridesmaids?\nRachel: Oh God... well, it started about a half hour before the wedding. I was in the room where we were keeping all the presents, and I was looking at this gravy boat. This really gorgeous Lamauge gravy boat. When all of a sudden- (to the waitress that brought her coffee)Sweet \'n\' Lo?- I realized that I was mor ...
#   {'scene_no': 1,
#    'scene_mark': "[Scene: Monica's Apartment, everyone is there and watching a Spanish Soap on TV and are trying to figure out what is going on.]",
#    'dialog': "Monica: Now I'm guessing that he bought her the big pipe organ, and she's really not happy about it.\nChandler: (imitating the characters) Tuna or egg salad?  Decide!\nRoss: (in a deep voice) I'll have whatever Christine is having.\nRachel: (on phone) Daddy, I just... I can't marry him! I'm sorry. I just don't love him. Well, it matters to me!\n(The scene on TV has changed to show two women, one is holding her hair.)\nPhoebe:  If I let go of my hair, my head will fall off.\nChandler: (re TV) Ooh, she should not be wearing those pants.\nJoey: I say push her down the stairs.\nPhoebe, Ross, Chandler, and Joey:  Push her down the stairs! Push her down the stairs! Push her down the stairs!\n(She is pushed down the stairs and everyone cheers.)\nRachel: C'mon Daddy, listen to me! It's like, it's like, all of my life, everyone has always told me, 'You're a shoe! You're a shoe, you're a shoe, you're a shoe!'. And today I just stopped and I said, 'What if I don't wanna be a shoe? What if I wanna be a- a purse, y'know? Or a- or a hat! No, I'm not saying I want you to buy me a hat, I'm saying I am a ha- It's a metaphor, Daddy!\nRoss: You can see where he'd have trouble.\nRachel: Look Daddy, it's my life. Well maybe I'll just stay here with Monica.\nMonica: Well, I guess we've established who's staying here with Monica...\nRachel: Well, maybe that's my decision. Well, maybe I don't need your money. Wait!! Wait, I said maybe!!\n[Time Lapse, Rachel is breating into a paper bag.]\nMonica: Just breathe, breathe.. that's it. Just try to think of nice calm things...\nPhoebe: (sings) Raindrops on roses and rabbits and kittens, (Rachel and Monica turn to look at her.) bluebells and sleighbells and- something with mittens... La la la la...something and noodles with string.  These are a few...\nRachel: I'm all better now.\nPhoebe: (grins and walks to the kitchen and says to Chandler and Joey.) I helped!\nMonica: Okay, look, this is probably for the best, y'know? Independence. Taking control of your life.  The whole, 'hat' thing.\nJoey: (comforting her) And hey, you need anything, you can always come to Joey. Me and Chandler live across the hall. And he's away a lot.\nMonica: Joey, stop hitting on her! It's her wedding day!\nJoey: What, like there's a rule or something?\n(The door buzzer sounds and Chandler gets it.)\nChandler: Please don't do that again, it's a horrible sound.\nPaul: (over the intercom) It's, uh, it's Paul.\nMonica: Oh God, is it 6:30?  Buzz him in!\nJoey: Who's Paul?\nRoss: Paul the Wine Guy, Paul?\nMonica: Maybe. Joey: Wait. Your 'not a real date' tonight is with Paul the Wine Guy?\nRoss: He finally asked you out?\nMonica: Yes!\nChandler: Ooh, this is a Dear Diary moment.\nMonica: Rach, wait, I can cancel...\nRachel: Please, no, go, that'd be fine!\nMonica: (to Ross) Are, are you okay? I mean, do you want me to stay?\nRoss: (choked voice) That'd be good...\nMonica: (horrified) Really?\nRoss: (normal voice) No, go on! It's Paul the Wine Guy!\nPhoebe: What does that mean?   Does he sell it, drink it, or just complain a lot? (Chandler doesn't know.)\n(There's a knock on the door and it's Paul.)\nMonica: Hi, come in! Paul, this is.. (They are all lined up next to the door.)... everybody, everybody, this is Paul.\nAll: Hey! Paul! Hi! The Wine Guy! Hey!\nChandler: I'm sorry, I didn't catch your name. Paul, was it?\nMonica: Okay, umm-umm, I'll just--I'll be right back, I just gotta go ah, go ah...\nRoss: A wandering?\nMonica: Change!  Okay, sit down. (Shows Paul in) Two seconds.\nPhoebe: Ooh, I just pulled out four eyelashes. That can't be good.\n(Monica goes to change.)\nJoey:  Hey, Paul!\nPaul: Yeah?\nJoey: Here's a little tip, she really likes it when you rub her neck in the same spot over and over and over again until it starts to get a little red.\nMonica: (yelling from the bedroom) Shut up, Joey!\nRoss: So Rachel, what're you, uh... what're you up to tonight?\nRachel: Well, I was kinda supposed to be headed for Aruba  ...
#   {'scene_no': 2,
#    'scene_mark': '[Scene: The Subway, Phoebe is singing for change.]',
#    'dialog': 'Phoebe: (singing) Love is sweet as summer showers, love is a wondrous work of art, but your love oh your love, your love...is like a giant pigeon...crapping on my heart.  La-la-la-la-la- (some guy gives her some change and to that guy) Thank you. (sings) La-la-la-la...ohhh!\n'},
#   {'scene_no': 3,
#    'scene_mark': "[Scene: Ross's Apartment, the guys are there assembling furniture.]",
#    'dialog': "Ross: (squatting and reading the instructions) I'm supposed to attach a brackety thing to the side things, using a bunch of these little worm guys. I have no brackety thing, I see no whim guys whatsoever and- I cannot feel my legs.\n(Joey and Chandler are finishing assembling the bookcase.)\nJoey: I'm thinking we've got a bookcase here.\nChandler: It's a beautiful thing.\nJoey: (picking up a leftover part) What's this?\nChandler: I would have to say that is an 'L'-shaped bracket.\nJoey: Which goes where?\nChandler: I have no idea.\n(Joey checks that Ross is not looking and dumps it in a plant.)\nJoey: Done with the bookcase!\nChandler: All finished!\nRoss: (clutching a beer can and sniffing) This was Carol's favorite beer. She always drank it out of the can, I should have known.\nJoey: Hey-hey-hey-hey, if you're gonna start with that stuff we're outta here.\nChandler: Yes, please don't spoil all this fun.\nJoey: Ross, let me ask you a question. She got the furniture, the stereo, the good TV- what did you get?\nRoss: You guys.\nChandler: Oh, God.\nJoey: You got screwed.\nChandler: Oh my God!\n"},
#   {'scene_no': 4,
#    'scene_mark': '[Scene: A Restaurant, Monica and Paul are eating.]',
#    'dialog': "Monica: Oh my God!\nPaul: I know, I know, I'm such an idiot. I guess I should have caught on when she started going to the dentist four and five times a week. I mean, how clean can teeth get?\nMonica: My brother's going through that right now, he's such a mess. How did you get through it?\nPaul: Well, you might try accidentally breaking something valuable of hers, say her-\nMonica: -leg?\nPaul: (laughing) That's one way! Me, I- I went for the watch.\nMonica: You actually broke her watch?  Wow!  The worst thing I ever did was, I-I shredded by boyfriend's favorite bath towel.\nPaul: Ooh, steer clear of you.\nMonica: That's right. \n"},
#   {'scene_no': 5,
#    'scene_mark': "[Scene: Monica's Apartment, Rachel is talking on the phone and pacing.]",
#    'dialog': "Rachel: Barry, I'm sorry... I am so sorry... I know you probably think that this is all about what I said the other day about you making love with your socks on, but it isn't... it isn't, it's about me, and I ju- (She stops talking and dials the phone.) Hi, machine cut me off again... anyway...look, look, I know that some girl is going to be incredibly lucky to become Mrs. Barry Finkel, but it isn't me, it's not me.  And not that I have any idea who me is right now, but you just have to give me a chance too... (The maching cuts her off again and she redials.)\n"},
#   {'scene_no': 6,
#    'scene_mark': "[Scene: Ross's Apartment; Ross is pacing while Joey and Chandler are working on some more furniture.]",
#    'dialog': "Ross: I'm divorced!  I'm only 26 and I'm divorced!\nJoey: Shut up!\nChandler: You must stop! (Chandler hits what he is working on with a hammer and it collapses.)\nRoss: That only took me an hour.\nChandler: Look, Ross, you gotta understand, between us we haven't had a relationship that has lasted longer than a Mento.   You, however have had the love of a woman for four years.   Four years of closeness and sharing at the end of which she ripped your heart out, and that is why we don't do it!  I don't think that was my point!\nRoss: You know what the scariest part is? What if there's only one woman for everybody, y'know? I mean what if you get one woman- and that's it? Unfortunately in my case, there was only one woman- for her...\nJoey: What are you talking about? 'One woman'? That's like saying there's only one flavor of ice cream for you. Lemme tell you something, Ross. There's lots of flavors out there. There's Rocky Road, and Cookie Dough, and Bing! Cherry Vanilla. You could get 'em with Jimmies, or nuts, or whipped cream! This is the best thing that ever happened to you! You got married, you were, like, what, eight? Welcome back to the world! Grab a spoon!\nRoss: I honestly don't know if I'm hungry or horny.\nChandler: Stay out of my freezer! \n"},
#   {'scene_no': 7,
#    'scene_mark': '[Scene: A Restaurant, Monica and Paul are still eating.]',
#    'dialog': "Paul: Ever since she walked out on me, I, uh...\nMonica: What?..... What, you wanna spell it out with noodles?\nPaul: No, it's, it's more of a fifth date kinda revelation.\nMonica: Oh, so there is gonna be a fifth date?\nPaul: Isn't there?\nMonica: Yeah... yeah, I think there is. -What were you gonna say?\nPaul: Well, ever-ev-... ever since she left me, um, I haven't been able to, uh, perform. (Monica takes a sip of her drink.) ...Sexually.\nMonica: (spitting out her drink in shock) Oh God, oh God, I am sorry... I am so sorry...\nPaul: It's okay...\nMonica: I know being spit on is probably not what you need right now. Um... how long?\nPaul: Two years.\nMonica: Wow! I'm-I'm-I'm glad you smashed her watch!\nPaul: So you still think you, um... might want that fifth date?\nMonica: (pause)...Yeah. Yeah, I do.\n"},
#   {'scene_no': 8,
#    'scene_mark': "[Scene: Monica's Apartment, Rachel is watching Joanne Loves Chaci.]",
#    'dialog': "Priest on TV: We are gathered here today to join Joanne Louise Cunningham and Charles, Chachi-Chachi-Chachi, Arcola in the bound of holy matrimony.\nRachel: Oh...see... but Joanne loved Chachi! That's the difference!\n"},
#   {'scene_no': 9,
#    'scene_mark': "[Scene: Ross's Apartment, they're all sitting around and talking.]",
#    'dialog': "Ross: (scornful) Grab a spoon. Do you know how long it's been since I've grabbed a spoon? Do the words 'Billy, don't be a hero' mean anything to you?\nJoey: Great story!  But, I uh, I gotta go, I got a date with Andrea--Angela--Andrea...  Oh man, (looks to Chandler)\nChandler: Angela's the screamer, Andrea has cats.\nJoey: Right.  Thanks.  It's June.  I'm outta here. (Exits.)\nRoss: Y'know, here's the thing. Even if I could get it together enough to- to ask a woman out,... who am I gonna ask? (He gazes out of the window.)\n[Cut to Rachel staring out of her window.]\nCommercial Break\n"},
#   {'scene_no': 10,
#    'scene_mark': "[Scene: Monica's Apartment, Rachel is making coffee for Joey and Chandler.]",
#    'dialog': 'Rachel: Isn\'t this amazing? I mean, I have never made coffee before in my entire life.\nChandler: That is amazing.\nJoey: Congratulations.\nRachel: Y\'know, I figure if I can make coffee, there isn\'t anything I can\'t do.\nChandler: If can invade Poland, there isn\'t anything I can\'t do.\nJoey: Listen, while you\'re on a roll, if you feel like you gotta make like a Western omelet or something... (Joey and Chandler taste the coffee, grimace, and pour it into a plant pot.) Although actually I\'m really not that hungry...\nMonica: (entering, to herself) Oh good, Lenny and Squigy are here.\nAll: Morning. Good morning.\nPaul: (entering from Monica\'s room) Morning.\nJoey: Morning, Paul.\nRachel: Hello, Paul.\nChandler: Hi, Paul, is it?\n(Monica and Paul walk to the door and talk in a low voice so the others can\'t hear.  The others move Monica\'s table closer to the door so that they can.)\nPaul: Thank you!  Thank you so much!\nMonica: Stop!\nPaul: No, I\'m telling you last night was like umm, all my birthdays, both graduations, plus the barn raising scene in Witness.\nMonica: We\'ll talk later.\nPaul: Yeah. (They kiss) Thank you. (Exits)\nJoey: That wasn\'t a real date?! What the hell do you do on a real date?\nMonica: Shut up, and put my table back.\nAll: Okayyy! (They do so.)\nChandler: All right, kids, I gotta get to work. If I don\'t input those numbers,... it doesn\'t make much of a difference...\nRachel: So, like, you guys all have jobs?\nMonica: Yeah, we all have jobs. See, that\'s how we buy stuff.\nJoey: Yeah, I\'m an actor.\nRachel: Wow! Would I have seen you in anything?\nJoey: I doubt it. Mostly regional work.\nMonica: Oh wait, wait, unless you happened to catch the Reruns\' production of Pinocchio, at the little theater in the park.\nJoey: Look, it was a job all right?\nChandler: \'Look, Gippetto, I\'m a real live boy.\'\nJoey: I will not take this abuse. (Walks to the door and opens it to leave.)\nChandler: You\'re right, I\'m sorry. (Burst into song and dances out of the door.) "Once I was a wooden boy, a little wooden boy..."\nJoey: You should both know, that he\'s a dead man.  Oh, Chandler? (Starts after Chandler.)\nMonica: So how you doing today? Did you sleep okay? Talk to Barry? I can\'t stop smiling.\nRachel: I can see that. You look like you slept with a hanger in your mouth.\nMonica: I know, he\'s just so, so... Do you remember you and Tony DeMarco?\nRachel: Oh, yeah.\nMonica: Well, it\'s like that. With feelings.\nRachel: Oh wow. Are you in trouble.\nMonica: Big time!\nRachel: Want a wedding dress?   Hardly used.\nMonica: I think we are getting a little ahead of selves here. Okay. Okay. I am just going to get up, go to work and not think about him all day. Or else I\'m just gonna get up and go to work.\nRachel: Oh, look, wish me luck!\nMonica: What for?\nRachel: I\'m gonna go get one of those (Thinks) job things.\n(Monica exits.)\n'},
#   {'scene_no': 11,
#    'scene_mark': '[Scene: Iridium, Monica is working as Frannie enters.]',
#    'dialog': "Frannie: Hey, Monica!\nMonica: Hey Frannie, welcome back! How was Florida?\nFrannie: You had sex, didn't you?\nMonica: How do you do that?\nFrannie: Oh, I hate you, I'm pushing my Aunt Roz through Parrot Jungle and you're having sex!  So? Who?\nMonica: You know Paul?\nFrannie: Paul the Wine Guy? Oh yeah, I know Paul.\nMonica: You mean you know Paul like I know Paul?\nFrannie: Are you kidding? I take credit for Paul. Y'know before me, there was no snap in his turtle for two years.\n"},
#   {'scene_no': 12,
#    'scene_mark': '[Scene: Central Perk, everyone but Rachel is there.]',
#    'dialog': "Joey: (sitting on the arm of the couch)Of course it was a line!\nMonica: Why?! Why? Why, why would anybody do something like that?\nRoss: I assume we're looking for an answer more sophisticated than 'to get you into bed'.\nMonica: I hate men!  I hate men!\nPhoebe: Oh no, don't hate, you don't want to put that out into the universe.\nMonica: Is it me? Is it like I have some sort of beacon that only dogs and men with severe emotional problems can hear?\nPhoebe: All right, c'mere, gimme your feet. (She starts massaging them.)\nMonica: I just thought he was nice, y'know?\nJoey: (bursts out laughing again) I can't believe you didn't know it was a line!\n(Monica pushes him off of the sofa as Rachel enters with a shopping bag.)\nRachel: Guess what?\nRoss: You got a job?\nRachel: Are you kidding? I'm trained for nothing! I was laughed out of twelve interviews today.\nChandler: And yet you're surprisingly upbeat.\nRachel: You would be too if you found John and David boots on sale, fifty percent off!\nChandler: Oh, how well you know me...\nRachel: They're my new 'I don't need a job, I don't need my parents, I've got great boots' boots!\nMonica: How'd you pay for them?\nRachel: Uh, credit card.\nMonica: And who pays for that?\nRachel: Um... my... father.\n"},
#   {'scene_no': 13,
#    'scene_mark': "[Scene: Monica and Rachel's, everyone is sitting around the kitchen table.   Rachel's credit cards are spread out on the table along with a pair of scissors.]",
#    'dialog': 'Rachel: Oh God, come on you guys, is this really necessary?  I mean, I can stop charging anytime I want.\nMonica: C\'mon, you can\'t live off your parents your whole life.\nRachel: I know that. That\'s why I was getting married.\nPhoebe: Give her a break, it\'s hard being on your own for the first time.\nRachel: Thank you.\nPhoebe: You\'re welcome. I remember when I first came to this city. I was fourteen. My mom had just killed herself and my step-dad was back in prison, and I got here, and I didn\'t know anybody. And I ended up living with this albino guy who was, like, cleaning windshields outside port authority, and then he killed himself, and then I found aromatherapy. So believe me, I know exactly how you feel.\n(Pause)\nRoss: The word you\'re looking for is \'Anyway\'...\nMonica: All right, you ready?\nRachel: No.  No, no, I\'m not ready!  How can I be ready?  "Hey, Rach!  You ready to jump out the airplane without your parachute?"  Come on, I can\'t do this!\nMonica: You can, I know you can!\nRachel: I don\'t think so.\nRoss: Come on, you made coffee!   You can do anything! (Chandler slowly tries to hide the now dead plant from that morning when he and Joey poured their coffee into it.)\nRoss: C\'mon, cut. Cut, cut, cut,...\nAll: Cut, cut, cut, cut, cut, cut, cut... (She cuts one of them and they cheer.)\nRachel: Y\'know what?  I think we can just leave it at that.  It\'s kinda like a symbolic gesture...\nMonica:  Rachel!  That was a library card!\nAll: Cut, cut, cut, cut, cut, cut, cut..\nChandler: (as Rachel is cutting up her cards) Y\'know, if you listen closely, you can hear a thousand retailers scream.\n(She finishes cutting them up and they all cheer.)\nMonica: Welcome to the real world! It sucks. You\'re gonna love it!\n[Time Lapse, Rachel and Ross are watching a TV channel finishes it\'s broadcast day by playing the national anthem.]\nMonica: Well, that\'s it (To Ross) You gonna crash on the couch?\nRoss: No. No, I gotta go home sometime.\nMonica: You be okay?\nRoss: Yeah.\nRachel: Hey Mon, look what I just found on the floor. (Monica smiles.) What?\nMonica: That\'s Paul\'s watch. You just put it back where you found it. Oh boy. Alright. Goodnight, everybody.\nRoss and Rachel: Goodnight.\n(Monica stomps on Paul\'s watch and goes into her room.)\nRoss: Mmm. (They both reach for the last cookie) Oh, no-\nRachel: Sorry-\nRoss: No no no, go-\nRachel: No, you have it, really, I don\'t want it-\nRoss: Split it?\nRachel: Okay.\nRoss: Okay. (They split it.) You know you probably didn\'t know this, but back in high school, I had a, um, major crush on you.\nRachel: I knew.\nRoss: You did! Oh.... I always figured you just thought I was Monica\'s geeky older brother.\nRachel: I did.\nRoss: Oh. Listen, do you think- and try not to let my intense vulnerability become any kind of a factor here- but do you think it would be okay if I asked you out? Sometime? Maybe?\nRachel: Yeah, maybe...\nRoss: Okay... okay, maybe I will...\nRachel: Goodnight.\nRoss: Goodnight.\n(Rachel goes into her room and Monica enters the living room as Ross is leaving.)\nMonica: See ya.... Waitwait, what\'s with you?\nRoss: I just grabbed a spoon. (Ross exits and Monica has no idea what that means.)\nClosing Credits\n'},
#   {'scene_no': 14,
#    'scene_mark': '[Scene: Central Perk, everyone is there.]',
#    'dialog': "Joey: I can't believe what I'm hearing here.\nPhoebe: (sings) I can't believe what I'm hearing here...\nMonica: What? I-I said you had a-\nPhoebe: (sings) What I said you had...\nMonica: (to Phoebe) Would you stop?\nPhoebe: Oh, was I doing it again?\nAll: Yes!\nMonica: I said that you had a nice butt, it's just not a great butt.\nJoey: Oh, you wouldn't know a great butt if it came up and bit ya.\nRoss: There's an image.\nRachel: (walks up with a pot of coffee) Would anybody like more coffee?\nChandler: Did you make it, or are you just serving it?\nRachel: I'm just serving it.\nAll: Yeah. Yeah, I'll have a cup of coffee.\nChandler: Kids, new dream... I'm in Las Vegas. (Rachel sits down to hear Chandler's dream.)\nCustomer: (To Rachel) Ahh, miss?   More coffee?\nRachel: Ugh. (To another customer that's leaving.) Excuse me, could you give this to that guy over there? (Hands him the coffee pot.) Go ahead. (He does so.) Thank you. (To the gang.) Sorry.  Okay, Las Vegas.\nChandler: Okay, so, I'm in Las Vegas... I'm Liza Minelli-\nEnd\n"}]}

# %% [markdown]
# ---

# %% [markdown]
# # Get dialogs in all episodes

# %%
# Open the driver
DRIVER_PATH = '../bin/chromedriver'
driver = webdriver.Chrome(executable_path = DRIVER_PATH)

# Main url
url = 'https://fangj.github.io/friends/'

# Access to main url
driver.get(url)

# List of season name
list_season = [element.text for element in driver.find_elements_by_tag_name('h3')]

# Dictionary with blank list
dict_season = {key: [] for key in list_season}

# Loop each season
for i in range(len(dict_season)):
    # Elements in each season
    episodes = driver.find_elements_by_tag_name('ul')[i].find_elements_by_tag_name('a')
    
    # Loop the episodes in season
    for j in range(len(episodes)):
        # Get episode name and url
        dict_episode = {
            'title': episodes[j].text,
            'url': episodes[j].get_attribute('href')
        }
        
        # Dictionary key
        dict_key = list(dict_season.keys())[i]
        
        # Appen the urls
        dict_season[dict_key].append(dict_episode)

# Loop episodes
for season in dict_season.keys():
    # Selected season
    selected_season = dict_season[season]
    for l_episode in range(len(selected_season)):
        # Selected episode
        selected_episode = selected_season[l_episode]
        # URL episode
        url_episode = selected_episode['url']
        
        # Access to url
        driver.get(url_episode)
        
        # Get metadata in episode
        try:
            raw_metadata = driver.find_element_by_tag_name('p').text        
        except:
            pass
        # Written by
        try:
            written_by = re.findall(pattern = 'Written by:\s*(.+)', string = raw_metadata)[0]
        except:
            written_by = None
        # Transcribed by
        try:
            transcribed_by = re.findall(pattern = 'Transcribed by:\s*(.+)', string = raw_metadata)[0]
        except:
            transcribed_by = None
        # Transcribing by
        try:
            transcribing_by = re.findall(pattern = 'Additional transcribing by:\s*(.+)', string = raw_metadata)[0]
        except:
            transcribing_by = None
        # Note
        try:
            note = re.findall(pattern = '\\(?Note:\s*(.+)\\)$', string = raw_metadata)[0]
        except:
            note = None

        # Store the metadata
        metadata = {
            'season': season,
            'title': selected_episode['title'],
            'written_by': written_by,
            'transcribed_by': transcribed_by,
            'additional_transcribing_by': transcribing_by,
            'note': note
        }
        
        # Get the dialog
        l = driver.find_elements_by_tag_name('p')

        # Create a empty list
        list_ = []

        # Dialog is not in standard format
        if len(l) < 50:
            # Long text
            long_text = []

            # Check length of l
            if len(l) > 0 and len(l) != 1:
                # Loop
                for elem in l:
                    if len(elem.text) > 50:
                        # Get the long text dialog
                        long_text_ = elem.text.split('\n')
                        # Remove the multiple new lines
                        long_text_ = list(filter(lambda x: x != '', long_text_))
                        long_text += long_text_
            else:
                # Get the long text dialog
                long_text_ = driver.find_element_by_tag_name('html').text.split('\n')
                # Remove the multiple new lines
                long_text_ = list(filter(lambda x: x != '', long_text_))
                long_text += long_text_

            # Parameters
            stat_long = True
            stat = True
            i = 0
            j = 0
        else:
            # Parameters
            stat_long = False
            stat = True
            i = 1
            j = 0

        # Main loops
        while stat:
            try:
                # String
                if stat_long:
                    string_ = long_text[i]
                else:
                    string_ = l[i].text
                # Scene play
                try:
                    scene_play = re.search(pattern = '\\[Scene.+?[\\]|\\)]', string = string_)
                    # String of scene
                    scene_text = scene_play.group(0)
                except:
                    scene_text = '[Scene: Beginning of Episode (Generated)]'
                # Status of scene
                stat_loop = bool(scene_play)

                # If first index is not scene description
                if not stat_loop and i == 1:
                    stat_loop = True
                    k = i
                else:
                    # First increment
                    k = i + 1

                # Dictionary for dialog
                dict_ = {
                    'scene_no': j,
                    'scene_mark': scene_text,
                    'dialog': ''
                }

                # Secondary loops
                while stat_loop:
                    try:
                        # String
                        if stat_long:
                            string_loop = long_text[k]
                        else:
                            string_loop = l[k].text
                        # Scene play
                        scene_play_loop = re.search(pattern = '\\[Scene.+?[\\]|\\)]', string = string_loop)
                        # Status of scene
                        stat_loop = not bool(scene_play_loop)

                        # Update the dialog in dictionary
                        if stat_loop:
                            dict_['dialog'] += string_loop + '\n'
                            k += 1
                        else:
                            # Scene within dialog
                            if len(string_loop) != len(scene_play_loop.group(0)):
                                string_loop_trunc = re.sub(pattern = '\\[Scene.+?[\\]|\\)]', string = string_loop, repl = '')
                                dict_['dialog'] += string_loop_trunc + '\n'
                    except:
                        # Stop secondary loop
                        stat_loop = False

                # Append the scene in one episode
                list_.append(dict_)

                # Update parameters
                i = k
                j += 1

            except:
                # Stop main loop
                stat = False
        
        # File for one episode
        episode_ = {
            'metadata': metadata,
            'data': list_
        }
        
        # Create a directory
        path = '../data/' + season
        Path(path).mkdir(parents = True, exist_ok = True)
        
        # Serialize json
        json_object = json.dumps(episode_, indent = 4)
        # Write to JSON
        file_name = selected_episode['title'].translate(str.maketrans('', '', string.punctuation))
        filename = path + '/{season_name}-{episode_name}.json'.format(
            season_name = season,
            episode_name = file_name
        )
        
        with open(filename, 'w') as outfile:
            outfile.write(json_object)
